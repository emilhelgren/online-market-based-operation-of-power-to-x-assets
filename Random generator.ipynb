# %%
import numpy as np

# %%
E_forecast = [
    5,      # 1
    6,      # 2
    7,      # 3
    8,      # 4
    3,      # 5
    5.5,    # 6
    6.2,    # 7
    7.2,    # 8
    12,     # 9
    1.1,    # 10
]

# %%
np.random.rand(10) - 0.5
# Out:
# array([-0.40306416, -0.27295418,  0.17529272, -0.04035053, -0.06424059,
#        -0.39669581,  0.35693065, -0.26102877, -0.31041123, -0.22175083])

# %%
np.array([0.94423281, 1.17482697, 0.68934189, 1.50722456, 1.13033861,
       1.55988187, 0.8699497 , 0.819744  , 1.32419046, 0.7800745 ]).mean()
# Out:
# 1.079980537

# %%
import matplotlib.pyplot as plt

# %%
prices = [0.81, 0.8200000000000001, 0.8300000000000001, 0.8400000000000001, 0.8500000000000001, 0.8600000000000001, 0.8700000000000001, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.9400000000000001, 0.9500000000000001, 0.9600000000000001, 0.9700000000000001, 0.98, 0.99, 1.0, 1.01, 1.02, 1.03, 1.04, 1.05, 1.06, 1.07, 1.08, 1.09, 1.1, 1.11, 1.12, 1.1300000000000001, 1.1400000000000001, 1.1500000000000001, 1.1600000000000001, 1.17, 1.1800000000000002, 1.19, 1.2000000000000002]

q_values = [[1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [1.0344737556121706, 0.0], [0.0, 1.0344737556121706], [0.0, 1.0344737556121706], [0.0, 1.0344737556121706], [0.0, 1.0344737556121708], [0.0, 1.0344737556121708], [0.0, 1.0344737556121708], [0.0, 1.103940608857772], [0.0, 1.103940608857772], [0.0, 1.103940608857772], [0.0, 1.1039406088577703], [0.0, 1.1039406088577703], [0.0, 1.1039406088577703], [0.0, 1.1039406088577703], [0.0, 1.1039406088577703], [0.0, 1.1039406088577703], [0.0, 1.1039406088577703], [0.0, 1.1494533303809693], [0.0, 1.1494533303809693], [0.0, 1.1494533303809693], [0.0, 1.1494533303809693]]
q_F = []
q_H = []
for q_pair in q_values:
    q_F.append(q_pair[0])
    q_H.append(q_pair[1])


fig = plt.figure()
ax1 = fig.add_subplot()
ax1.plot(prices, q_F, 'go', label="Forward coefficient")
ax1.plot(prices, q_H, 'o', label="Hydrogen coefficient")
ax1.set_xlabel("Hydrogen price")
ax1.set_ylabel("Coefficient value")

plt.legend()
plt.show()

# %%
prices = np.arange(0, 2, step=0.001)
outline = []
bids = []

for price in prices:
    outline.append(1)
    if (price < 1):
        bids.append(0)
    else:
        bids.append(1)


fig = plt.figure()
ax1 = fig.add_subplot()
ax1.plot(prices, outline, 'r--')
ax1.plot(prices, bids, '-', label="Forward market bid")
# ax1.plot(prices, q_H, 'o', label="Hydrogen coefficient")
# ax1.set_xlabel("Forward price")
ax1.set_ylabel("Production value")

plt.yticks(np.arange(0, 1))  # Set label locations.
plt.yticks(np.arange(2), ['0', 'Production forecast'])  # Set text labels.

plt.xticks(np.arange(0, 2))  # Set label locations.
plt.xticks(np.arange(3), ['0', 'Hydrogen Price', ''])  # Set text labels.

plt.legend()
plt.show()

# %%
hyd = []
forward = []

for i in range(100):
    hyd.append(189.80703701679926)
    forward.append(100+np.random.randn(1)*10)


fig = plt.figure()
ax1 = fig.add_subplot()
ax1.plot(range(100), hyd, 'r-', label="Hydrogen price")
ax1.plot(range(100), forward, 'b-', label="Forward market price")
# ax1.plot(prices, q_H, 'o', label="Hydrogen coefficient")
ax1.set_xlabel("Time [h]")
ax1.set_ylabel("Price [EUR/MWh]")

# plt.yticks(np.arange(0, 1))  # Set label locations.
# plt.yticks(np.arange(2), ['0', 'x_t*q'])  # Set text labels.

plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_real = pd.read_csv('./data/realized.csv')
df_fore = pd.read_csv('./data/forecasts.csv')

# %%
df_real.iloc[:, 1]
# Out:
# 0       265.0
# 1       340.0
# 2       272.0
# 3       214.0
# 4       208.0
#         ...
# 8755     94.0
# 8756     81.0
# 8757     65.0
# 8758     73.0
# 8759     59.0
# Name: Wind Offshore  - Actual Aggregated [MW], Length: 8760, dtype: float64

# %%
f = plt.figure()
# n = len(df_real)
n = 100
x = range(n)
offset = 1000
plt.plot(x, df_real.iloc[offset:offset+n, 1], 'g-')
plt.plot(x, df_fore.iloc[offset:offset+n, 1], 'r-')
plt.show()

# %%
df_diff = df_real.iloc[:, 1] - df_fore.iloc[:, 1]
df_diff.head()
# Out:
# 0    12.0
# 1    12.0
# 2    15.0
# 3     4.0
# 4     4.0
# dtype: float64

# %%
print(df_real.iloc[:, 1].max())
print(df_fore.iloc[:, 1].max())
# Out:
# 377.0
# 370.0

# %%
f = plt.figure()
n = len(df_real)
# n = 100
x = range(n)
offset = 0
plt.plot(x, df_diff[offset:offset+n]/377.0)
plt.show()

# %%
# Plot to display the time series, ACF and PACF
# This code was adapted from the blog Seanabu.com
def tsplot(y, lags=25, figsize=(10, 8), style='bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        plt.figure(figsize=figsize) # Set the size of the figure
        
        layout = (2, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))

        
        y.plot(ax=ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        plot_acf(y, lags=lags, ax=acf_ax)
        plot_pacf(y, lags=lags, ax=pacf_ax, method='ywm')


        plt.tight_layout()
    return
